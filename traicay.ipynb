# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from keras.models import Sequential 
from keras.utils import np_utils
from keras.layers import Dense,Activation,Dropout,LSTM,BatchNormalization
from keras.layers import Flatten
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_generator = ImageDataGenerator(rescale=1./255,validation_split=0.1,width_shift_range=0.2,height_shift_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
trainset='/content/drive/MyDrive/Colab Notebooks/Trái cây'

# %%
train_dataset=data_generator.flow_from_directory(trainset,
                                     target_size=(100,100),
                                     batch_size=128,
                                     class_mode='categorical',
                                     subset="training",
                                     shuffle=True,)
validation_set=data_generator.flow_from_directory(trainset,
                                              target_size=(100,100),
                                              batch_size=128,
                                              class_mode='categorical',
                                              subset="validation",
                                              shuffle=True)
# Out:
# Found 30 images belonging to 10 classes.
# Found 0 images belonging to 10 classes.

# %%
validation_set.class_indices
# Out:
# {'Mít': 0,
#  'bơ': 1,
#  'chuối': 2,
#  'dâu': 3,
#  'khế': 4,
#  'mãng cầu': 5,
#  'măng cụt': 6,
#  'ổi': 7,
#  'sầu riêng': 8,
#  'xoài': 9}

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same',input_shape=(100,100,3)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding ='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(train_dataset,batch_size=128,epochs=100,verbose=1,validation_data=validation_set)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.8741 - accuracy: 0.0667
# Epoch 2/100
# 1/1 [==============================] - 2s 2s/step - loss: 10.1241 - accuracy: 0.1000
# Epoch 3/100
# 1/1 [==============================] - 2s 2s/step - loss: 4.2774 - accuracy: 0.0667
# Epoch 4/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.8393 - accuracy: 0.1667
# Epoch 5/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.2902 - accuracy: 0.1000
# Epoch 6/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.2714 - accuracy: 0.1000
# Epoch 7/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.2518 - accuracy: 0.1667
# Epoch 8/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.2315 - accuracy: 0.2333
# Epoch 9/100
# 1/1 [==============================] - 2s 2s/step - loss: 2.1460 - accuracy: 0.4000
# Epoch 10/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.0827 - accuracy: 0.2667
# Epoch 11/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.9082 - accuracy: 0.2333
# Epoch 12/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.8346 - accuracy: 0.3333
# Epoch 13/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.7058 - accuracy: 0.3333
# Epoch 14/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.6075 - accuracy: 0.3333
# Epoch 15/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.3100 - accuracy: 0.5667
# Epoch 16/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.4503 - accuracy: 0.3333
# Epoch 17/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.2546 - accuracy: 0.6000
# Epoch 18/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.5460 - accuracy: 0.4333
# Epoch 19/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.4567 - accuracy: 0.3667
# Epoch 20/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.1760 - accuracy: 0.5667
# Epoch 21/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.1151 - accuracy: 0.6667
# Epoch 22/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.1218 - accuracy: 0.5333
# Epoch 23/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7936 - accuracy: 0.7667
# Epoch 24/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.1493 - accuracy: 0.5333
# Epoch 25/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.9346 - accuracy: 0.7667
# Epoch 26/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6612 - accuracy: 0.7667
# Epoch 27/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8244 - accuracy: 0.7000
# Epoch 28/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5678 - accuracy: 0.8000
# Epoch 29/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5190 - accuracy: 0.8333
# Epoch 30/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7686 - accuracy: 0.7667
# Epoch 31/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8993 - accuracy: 0.6333
# Epoch 32/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6101 - accuracy: 0.8667
# Epoch 33/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6993 - accuracy: 0.8333
# Epoch 34/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8125 - accuracy: 0.7333
# Epoch 35/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5721 - accuracy: 0.8333
# Epoch 36/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.9138 - accuracy: 0.6667
# Epoch 37/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6005 - accuracy: 0.7667
# Epoch 38/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8964 - accuracy: 0.6667
# Epoch 39/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6976 - accuracy: 0.8000
# Epoch 40/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7311 - accuracy: 0.6667
# Epoch 41/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.9362 - accuracy: 0.6667
# Epoch 42/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.0462 - accuracy: 0.5667
# Epoch 43/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6203 - accuracy: 0.7667
# Epoch 44/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4534 - accuracy: 0.9000
# Epoch 45/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5094 - accuracy: 0.7667
# Epoch 46/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7995 - accuracy: 0.6667
# Epoch 47/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4736 - accuracy: 0.8667
# Epoch 48/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3914 - accuracy: 0.8667
# Epoch 49/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4175 - accuracy: 0.9000
# Epoch 50/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4093 - accuracy: 0.8333
# Epoch 51/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5186 - accuracy: 0.7667
# Epoch 52/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2725 - accuracy: 0.9333
# Epoch 53/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4409 - accuracy: 0.8667
# Epoch 54/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2487 - accuracy: 0.9333
# Epoch 55/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3540 - accuracy: 0.8667
# Epoch 56/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6319 - accuracy: 0.8000
# Epoch 57/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6551 - accuracy: 0.7333
# Epoch 58/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1878 - accuracy: 0.9667
# Epoch 59/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.6209 - accuracy: 0.8333
# Epoch 60/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.9002 - accuracy: 0.6667
# Epoch 61/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2522 - accuracy: 0.9000
# Epoch 62/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5034 - accuracy: 0.8333
# Epoch 63/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4528 - accuracy: 0.8000
# Epoch 64/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2425 - accuracy: 0.9333
# Epoch 65/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1915 - accuracy: 0.9667
# Epoch 66/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4226 - accuracy: 0.9333
# Epoch 67/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2546 - accuracy: 0.9333
# Epoch 68/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2714 - accuracy: 0.9000
# Epoch 69/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2142 - accuracy: 0.9333
# Epoch 70/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2730 - accuracy: 0.9000
# Epoch 71/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1350 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1844 - accuracy: 0.9333
# Epoch 73/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1719 - accuracy: 0.9333
# Epoch 74/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1322 - accuracy: 0.9667
# Epoch 75/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4052 - accuracy: 0.8667
# Epoch 76/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1802 - accuracy: 0.9333
# Epoch 77/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2466 - accuracy: 0.8667
# Epoch 78/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2924 - accuracy: 0.9000
# Epoch 79/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1304 - accuracy: 0.9333
# Epoch 80/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2578 - accuracy: 0.9333
# Epoch 81/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1265 - accuracy: 0.9333
# Epoch 82/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2363 - accuracy: 0.9000
# Epoch 83/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1088 - accuracy: 0.9333
# Epoch 84/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0755 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5639 - accuracy: 0.9333
# Epoch 86/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2121 - accuracy: 0.9333
# Epoch 87/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1365 - accuracy: 0.9333
# Epoch 88/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1977 - accuracy: 0.9333
# Epoch 89/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1317 - accuracy: 0.9333
# Epoch 90/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0860 - accuracy: 0.9333
# Epoch 91/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.3403 - accuracy: 0.8667
# Epoch 92/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2831 - accuracy: 0.8667
# Epoch 93/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2612 - accuracy: 0.9333
# Epoch 94/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0706 - accuracy: 0.9667
# Epoch 95/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2174 - accuracy: 0.9333
# Epoch 96/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2381 - accuracy: 0.9000
# Epoch 97/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1408 - accuracy: 0.9333
# Epoch 98/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.4436 - accuracy: 0.9000
# Epoch 99/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0830 - accuracy: 0.9333

# %%
train_dataset=data_generator.flow_from_directory(trainset,
                                     target_size=(100,100),
                                     batch_size=128,
                                     class_mode='categorical',
                                     subset="training",
                                     shuffle=True,)
validation_set=data_generator.flow_from_directory(trainset,
                                              target_size=(100,100),
                                              batch_size=128,
                                              class_mode='categorical',
                                              subset="validation",
                                              shuffle=True)
# Out:
# Found 30 images belonging to 10 classes.
# Found 0 images belonging to 10 classes.

# %%
model.save('traicay.hs')
# Out:
# INFO:tensorflow:Assets written to: traicay.hs/assets

# %%
model1=load_model('traicay.hs')

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img=load_img('/content/DÂU TEST.jpg',target_size=(100,100))
img=img_to_array(img)
img=img.reshape(1,100,100,3)
img=img.astype('float32')
img=img/255
np.argmax(model1.predict(img),axis=-1)
# Out:
# array([3])

# %%
label = ['Mit','Sau rieng','Mang cut','oi','khe','mang cau','bo','chuoi','Dau','Xoai']

# %%
import numpy as np
from tensorflow.keras.utils import load_img,img_to_array
img = load_img('/content/DÂU TEST.jpg', target_size = (100,100))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,100,100,3) 
img = img.astype('float32')
img = img/255
print(label[np.argmax(model.predict(img))])
# Out:
# oi
